# %% [markdown]
# # Actividad 05 — Limpieza · Agraria.pe
#
# ## Objetivo
# Deduplicar por URL, normalizar fechas, limpiar titulares (caracteres especiales, encoding), conservar el texto completo para Fase 2 y agregar a conteo mensual de noticias.
#
# ## Decisión de diseño
# - El texto (`titular` + `cuerpo_completo`) se **conserva íntegro** en el dataset limpio para uso futuro con BETO.
# - Para esta fase (Fase 1) solo se extrae `n_noticias` por mes como variable numérica.
#
# ## Salida
# - `pipeline/output/05_limpieza/agraria_noticias_clean.csv` — Dataset completo con texto conservado
# - `pipeline/output/05_limpieza/agraria_mensual.csv` — Conteo mensual de noticias

# %%
# Por completar
