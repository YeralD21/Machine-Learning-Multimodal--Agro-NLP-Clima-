# %% [markdown]
# # Actividad 09 — ETL · Agraria.pe
#
# ## Objetivo
# Preparar la señal mensual de noticias para el merge multimodal: agregar conteo de noticias por mes, construir la clave `fecha_evento` y dejar el texto completo disponible para la Fase 2.
#
# ## Variables generadas para Fase 1
# - `n_noticias` — Conteo de noticias por mes (variable numérica para LSTM)
#
# ## Variables reservadas para Fase 2
# - `titular` + `cuerpo_completo` — Texto para análisis de sentimiento con BETO
#
# ## Salida
# - `pipeline/output/09_etl/agraria_mensual_etl.csv`

# %%
# Por completar
