# %% [markdown]
# # Actividad 05 — Limpieza · INDECI
#
# ## Objetivo
# Filtrar fenómenos relevantes para agricultura, estandarizar nombres geográficos, normalizar fechas, conservar campos de texto para Fase 2 (BETO) y agregar a granularidad mensual.
#
# ## Decisión de diseño
# Los campos de texto libre se **mantienen en el dataset** como columnas separadas (`descripcion_raw`) para uso futuro en NLP. No se procesan en esta fase.
#
# ## Salida
# - `pipeline/output/05_limpieza/indeci_eventos_clean.csv`

# %%
# Por completar
