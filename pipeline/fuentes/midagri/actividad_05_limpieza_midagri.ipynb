# %% [markdown]
# # Actividad 05 — Limpieza · MIDAGRI
#
# ## Objetivo
# Filtrar solo limón, aplicar remoción de outliers (IQR), estandarizar nombres geográficos, recortar al rango temporal 2021–2025 y agregar a granularidad mensual por departamento/provincia.
#
# ## Salida
# - `pipeline/output/05_limpieza/midagri_limon_clean.csv`

# %%
# Por completar
