# %% [markdown]
# # Actividad 05 — Limpieza · NASA POWER
#
# ## Objetivo
# Aplicar limpieza completa: reemplazar centinelas -999, imputar nulos de ALLSKY, estandarizar geografía (MAYÚSCULAS SIN TILDES, proteger Ñ) y **corregir PRECTOTCORR de mm/día a mm/mes** (multiplicar por días del mes).
#
# ## Corrección crítica
# `PRECTOTCORR` en los archivos fuente está en **mm/día** (promedio diario del mes). Para el modelo necesitamos el **total mensual en mm**:
# ```
# precip_mm_mes = PRECTOTCORR_mm_dia × dias_del_mes
# ```
# Esto fue un bug identificado en el pipeline anterior de referencia.
#
# ## Salida
# - `pipeline/output/05_limpieza/nasa_long_clean.csv`

# %%
# Por completar
