# %% [markdown]
# # Actividad 09 — ETL · NASA POWER
#
# ## Objetivo
# Transformar el dataset limpio de NASA a granularidad mensual, aplicar selección de variables, construir la clave `fecha_evento` (YYYY-MM) y preparar el dataset climático listo para el merge multimodal.
#
# ## Selección de variables
# Decisión documentada sobre qué variables conservar para el modelo LSTM:
# - Variables a evaluar: T2M, T2M_MAX, T2M_MIN, PRECTOTCORR, RH2M, QV2M, ALLSKY_SFC_SW_DWN, WS2M
# - Criterio: correlación con producción + no redundancia entre variables
#
# ## Salida
# - `pipeline/output/09_etl/nasa_mensual_integrado.csv`
# - `pipeline/output/09_etl/scaler_nasa.pkl`

# %%
# Por completar
